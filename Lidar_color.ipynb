# %% [markdown]
# # 0. Test parameters

# %%
import numpy as np

n_cameras = 3
ring_R = 0.1
# put camera on a ring on xy plane around z axis of the rig
theta = np.linspace(0, 360.0, n_cameras, endpoint=False)
camera_axes = 'ros'
rot_ros = np.array([-90.0, 0.0, -90.0])
rot = np.tile(rot_ros, (n_cameras, 1))
rot[:,-1] += theta
trans = np.zeros((n_cameras, 3))
trans[:, 0] = ring_R * np.cos(np.radians(theta))
trans[:, 1] = ring_R * np.sin(np.radians(theta))
camera_translate = trans
camera_rotate = rot

dimenvue_config = {
    # initial pose
    'chassis': {
        # (3,) array
        'world_chassis_translate': [0, 0, 0],
        # (3,) x->y->z order euler angles, extrinsic rotation (R = Rz * Ry * Rx)
        'world_chassis_rotate': [0, 0, 0],
    },
    
    'imu': {
        'chassis_imu_translate' : [0, 0, 0.0],
        'chassis_imu_rotate' : [0, 0, 0],
        'imu_rate' : 400,
        'enable': False,
    },

    'lidar' : {
        'chassis_lidar_translate' : [0, 0, 0.1],
        'chassis_lidar_rotate' : [0, 0, 0],
        'lidar_config_file' : "OS1_REV6_32ch10hz512res_noiseless",
        'enable': True,
    },

    'cameras' : {
        'chassis_cameras_translate' : [0, 0, 0.0],
        'chassis_cameras_rotate' : [0, 0, 0],
        'n_cameras' : n_cameras,
        'camera_translate' : camera_translate,
        'camera_rotate' : camera_rotate,
        'camera_axes' : camera_axes,
        'camera_fps' : 30,
        'calibrate_config': {
            'camera_resolution' : [1920, 1200],
            'camera_intrinsics' : [[957.8, 0.0, 960], [0.0, 957.8, 600], [0.0, 0.0, 1.0]],
            'pixel_size' : 3 * 1e-3,
            'f_stop' : 1.8,
            'focus_distance' : 8.9
        },
        'enable': True,
    }
}
# scene configuration
wall_size = 10.0
cell_size = 2.0
wall_distance = 10

# data serialize and deserialize
PICKLE_FILE = 'lidar_rgb_data.pkl'

# %% [markdown]
# # 1. Start Isaac Sim

# %%
import sys
import os
import signal

# Get the absolute path of the notebook's directory
notebook_dir = os.path.dirname(os.path.abspath('__file__'))+'/dimenvue_ws/'
# Add the notebook's directory to sys.path
sys.path.append(notebook_dir)
# cd to the notebook's directory
os.chdir(notebook_dir)

from isaacsim import SimulationApp

CONFIG = {
    'headless': False,
    'display_options': 3286
}

# Example for creating a RTX lidar sensor and publishing PointCloud2 data
simulation_app = SimulationApp(CONFIG)
simulation_app.update()

spinning = True
def sigint_handler(sig, frame):
    global spinning
    spinning = False
signal.signal(signal.SIGINT, sigint_handler)

kernel = get_ipython().kernel
kernel.pre_handler_hook = lambda: None
kernel.post_handler_hook = lambda: None

def spin(update_function, *args, **kwargs):
    global spinning
    print('gui can be used now. interrupt kernel to go back to notebook')
    while spinning:
        update_function(*args, **kwargs)
    spinning = True

def resume_gui():
    spin(lambda: simulation_app.update())
    
if CONFIG['headless']:
    del spin
    del resume_gui
# Out:
# Starting kit application with the following args:  ['/f/ov/pkg/isaac-sim-4.1.0/exts/omni.isaac.kit/omni/isaac/kit/simulation_app.py', '/f/ov/pkg/isaac-sim-4.1.0/apps/omni.isaac.sim.python.kit', '--/app/tokens/exe-path=/f/ov/pkg/isaac-sim-4.1.0/kit', '--/persistent/app/viewport/displayOptions=3286', '--/rtx/materialDb/syncLoads=True', '--/rtx/hydra/materialSyncLoads=True', '--/omni.kit.plugin/syncUsdLoads=True', '--/app/renderer/resolution/width=1280', '--/app/renderer/resolution/height=720', '--/app/window/width=1440', '--/app/window/height=900', '--/renderer/multiGpu/enabled=True', '--/app/fastShutdown=False', '--ext-folder', '/f/ov/pkg/isaac-sim-4.1.0/exts', '--ext-folder', '/f/ov/pkg/isaac-sim-4.1.0/apps', '--/physics/cudaDevice=0', '--portable']
# Passing the following args to the base kit application:  ['-f', '/home/linh/.local/share/jupyter/runtime/kernel-ee864e3c-656a-497b-9aac-8c23b2fe7553.json']
# [Warning] [omni.isaac.kit.simulation_app] Non-headless mode not supported with jupyter notebooks
# [Warning] [omni.isaac.kit.simulation_app] fast shutdown not supported with jupyter notebooks
# [0.084s] [ext: omni.kit.async_engine-0.0.0] startup
# [0.539s] [ext: omni.stats-1.0.1] startup
# [0.540s] [ext: omni.client-1.1.0] startup
# [0.571s] [ext: omni.datastore-0.0.0] startup
# [0.571s] [ext: omni.blobkey-1.1.0] startup
# [0.571s] [ext: omni.ujitso.default-1.0.0] startup
# [0.572s] [ext: omni.hsscclient-0.0.0] startup
# [0.572s] [ext: omni.rtx.shadercache.vulkan-1.0.0] startup
# [0.573s] [ext: omni.assets.plugins-0.0.0] startup
# [0.575s] [ext: omni.gpu_foundation-0.0.0] startup
# [0.583s] [ext: carb.windowing.plugins-1.0.0] startup
# [0.591s] [ext: omni.kit.renderer.init-0.0.0] startup
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 555.42.02     | Graphics API: Vulkan
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 4060          | Yes: 0 |     | 8434    MB | 10de      | 0          |
# |     |                                  |        |     |            | 2882      | 82fb92c9.. |
# |     |                                  |        |     |            | 1         |            |
# |=============================================================================================|
# | OS: 20.04.6 LTS (Focal Fossa) ubuntu, Version: 20.04.6, Kernel: 5.15.0-117-generic
# | XServer Vendor: The X.Org Foundation, XServer Version: 12013000 (1.20.13.0)
# | Processor: Intel(R) Core(TM) i9-10900K CPU @ 3.70GHz | Cores: 10 | Logical: 20
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 64147 | Free Memory: 52558
# | Total Page/Swap (MB): 1899 | Free Page/Swap: 723
# |---------------------------------------------------------------------------------------------|
# [1.625s] [ext: omni.kit.pipapi-0.0.0] startup
# [1.626s] [ext: omni.kit.pip_archive-0.0.0] startup
# [1.626s] [ext: omni.pip.compute-1.4.0] startup
# [1.627s] [ext: omni.kit.telemetry-0.5.0] startup
# [1.648s] [ext: omni.pip.cloud-1.1.3] startup
# [1.651s] [ext: omni.isaac.core_archive-2.3.0] startup
# [1.652s] [ext: omni.mtlx-0.1.0] startup
# [1.652s] [ext: omni.usd.config-1.0.4] startup
# [1.657s] [ext: omni.gpucompute.plugins-0.0.0] startup
# [1.658s] [ext: omni.usd.libs-1.0.1] startup
# [1.765s] [ext: omni.isaac.ml_archive-2.0.1] startup
# [1.765s] [ext: omni.kit.loop-isaac-1.2.0] startup
# [1.766s] [ext: omni.kit.test-0.0.0] startup
# [1.798s] [ext: omni.appwindow-1.1.8] startup
# [1.849s] [ext: omni.kit.renderer.core-1.0.1] startup
# [2.295s] [ext: omni.kit.renderer.capture-0.0.0] startup
# [2.297s] [ext: omni.kit.renderer.imgui-1.0.1] startup
# [2.388s] [ext: omni.ui-2.23.11] startup
# [2.399s] [ext: omni.kit.mainwindow-1.0.3] startup
# [2.400s] [ext: carb.audio-0.1.0] startup
# [2.420s] [ext: omni.uiaudio-1.0.0] startup
# [2.421s] [ext: omni.kit.uiapp-0.0.0] startup
# [2.421s] [ext: omni.usd.schema.geospatial-0.0.0] startup
# [2.527s] [ext: omni.anim.navigation.schema-106.0.2] startup
# [2.543s] [ext: omni.usd.schema.audio-0.0.0] startup
# [2.547s] [ext: omni.usd.schema.semantics-0.0.0] startup
# [2.556s] [ext: omni.usd.schema.anim-0.0.0] startup
# [2.576s] [ext: omni.usd.schema.omnigraph-1.0.0] startup
# [2.584s] [ext: omni.usd.schema.isaac-2.1.0] startup
# [2.592s] [ext: omni.usd.schema.scene.visualization-2.0.2] startup
# [2.593s] [ext: omni.usd.schema.physx-106.0.20] startup
# [2.643s] [ext: omni.usd.schema.omniscripting-1.0.0] startup
# [2.649s] [ext: omni.anim.graph.schema-106.0.2] startup
# [2.656s] [ext: omni.usd.schema.forcefield-106.0.20] startup
# [2.664s] [ext: omni.kit.window.popup_dialog-2.0.24] startup
# [2.669s] [ext: omni.graph.exec-0.9.3] startup
# [2.670s] [ext: omni.kit.widget.nucleus_connector-1.1.8] startup
# [2.672s] [ext: omni.kit.usd_undo-0.1.8] startup
# [2.672s] [ext: omni.kit.exec.core-0.13.2] startup
# [2.674s] [ext: omni.usd_resolver-1.0.0] startup
# [2.680s] [ext: omni.resourcemonitor-105.0.1] startup
# [2.681s] [ext: omni.kit.actions.core-1.0.0] startup
# [2.683s] [ext: omni.activity.core-1.0.1] startup
# [2.685s] [ext: omni.usd.core-1.2.11] startup
# [2.690s] [ext: omni.timeline-1.0.10] startup
# [2.692s] [ext: omni.kit.commands-1.4.9] startup
# [2.696s] [ext: usdrt.scenegraph-7.4.8] startup
# [2.752s] [ext: omni.kit.audiodeviceenum-1.0.1] startup
# [2.754s] [ext: omni.hydra.usdrt_delegate-7.4.7] startup
# [2.781s] [ext: omni.hydra.scene_delegate-0.3.3] startup
# [2.791s] [ext: omni.usd-1.11.2] startup
# [2.847s] [ext: omni.kit.notification_manager-1.0.8] startup
# [2.848s] [ext: omni.kit.clipboard-1.0.3] startup
# [2.849s] [ext: omni.kit.widget.path_field-2.0.9] startup
# [2.850s] [ext: omni.kit.collaboration.telemetry-1.0.0] startup
# [2.851s] [ext: omni.kit.helper.file_utils-0.1.8] startup
# [2.853s] [ext: omni.kit.widget.nucleus_info-1.0.2] startup
# [2.853s] [ext: omni.kit.widget.context_menu-1.2.1] startup
# [2.854s] [ext: omni.kit.widget.browser_bar-2.0.10] startup
# [2.855s] [ext: omni.kit.collaboration.channel_manager-1.0.11] startup
# [2.856s] [ext: omni.kit.widget.filebrowser-2.10.48] startup
# [2.861s] [ext: omni.kit.search_core-1.0.5] startup
# [2.861s] [ext: omni.kit.widget.options_menu-1.1.4] startup
# [2.865s] [ext: omni.kit.widget.searchable_combobox-1.0.6] startup
# [2.866s] [ext: omni.kit.widget.search_delegate-1.0.4] startup
# [2.867s] [ext: omni.ui.scene-1.9.3] startup
# [2.873s] [ext: omni.kit.widget.options_button-1.0.2] startup
# [2.874s] [ext: omni.kit.widget.settings-1.1.1] startup
# [2.876s] [ext: omni.kit.menu.utils-1.5.27] startup
# [2.892s] [ext: omni.kit.window.filepicker-2.10.34] startup
# [2.901s] [ext: omni.kit.widget.prompt-1.0.7] startup
# [2.902s] [ext: omni.kit.usd.layers-2.1.31] startup
# [2.913s] [ext: omni.kit.window.preferences-1.5.3] startup
# [2.922s] [ext: omni.kit.widget.live_session_management.ui-1.0.1] startup
# [2.924s] [ext: omni.kit.collaboration.presence_layer-1.0.8] startup
# [2.927s] [ext: omni.kit.widget.live_session_management-1.2.18] startup
# [2.929s] [ext: omni.inspect-1.0.1] startup
# [2.931s] [ext: omni.kit.widget.graph-1.12.8] startup
# [2.937s] [ext: omni.kit.widget.filter-1.1.4] startup
# [2.937s] [ext: omni.graph.core-2.170.3] startup
# [2.941s] [ext: omni.kit.window.extensions-1.4.9] startup
# [2.947s] [ext: omni.kit.hotkeys.core-1.3.3] startup
# [2.948s] [ext: omni.kit.context_menu-1.8.0] startup
# [2.950s] [ext: omni.mdl-52.0.1] startup
# [2.971s] [ext: omni.iray.libs-0.0.0] startup
# [2.976s] [ext: omni.kit.primitive.mesh-1.0.16] startup
# [2.980s] [ext: omni.kit.stage_template.core-1.1.21] startup
# [2.981s] [ext: omni.mdl.neuraylib-0.2.5] startup
# [2.982s] [ext: omni.ujitso.processor.texture-1.0.0] startup
# [2.983s] [ext: omni.kit.window.file_exporter-1.0.29] startup
# [2.985s] [ext: omni.kit.stage_templates-1.2.3] startup
# [2.987s] [ext: omni.volume-0.5.0] startup
# [2.989s] [ext: omni.ujitso.client-0.0.0] startup
# [2.990s] [ext: omni.kit.window.file_importer-1.1.11] startup
# [2.991s] [ext: omni.kit.window.drop_support-1.0.2] startup
# [2.991s] [ext: omni.kit.window.file-1.3.52] startup
# [2.994s] [ext: omni.kit.window.content_browser_registry-0.0.6] startup
# [2.995s] [ext: omni.hydra.rtx-0.2.0] startup
# [3.015s] [ext: omni.kit.widget.highlight_label-1.0.2] startup
# [3.016s] [ext: omni.kit.window.content_browser-2.9.14] startup
# [3.035s] [ext: omni.kit.widget.stage-2.10.26] startup
# [3.047s] [ext: omni.kit.material.library-1.4.4] startup
# [3.055s] [ext: omni.kit.hydra_texture-1.2.6] startup
# [3.062s] [ext: omni.kit.viewport.legacy_gizmos-1.0.15] startup
# [3.067s] [ext: omni.kit.raycast.query-1.0.5] startup
# [3.079s] [ext: omni.hydra.engine.stats-1.0.2] startup
# [3.084s] [ext: omni.kit.widget.searchfield-1.1.6] startup
# [3.086s] [ext: omni.kit.widget.viewport-106.0.3] startup
# [3.090s] [ext: omni.kit.viewport.registry-104.0.6] startup
# [3.090s]
# Warning: Possible version incompatibility. Attempting to load omni::fabric::IPath with version v0.2 against v0.1.
# Warning: Possible version incompatibility. Attempting to load omni::fabric::IPath with version v0.2 against v0.1.
# Warp 1.2.1 initialized:
#    CUDA Toolkit 11.8, Driver 12.5
#    Devices:
#      "cpu"      : "x86_64"
#      "cuda:0"   : "NVIDIA GeForce RTX 4060" (8 GiB, sm_89, mempool enabled)
#    Kernel cache:
#      /home/linh/.cache/warp/1.2.1
#  [ext: omni.kit.widget.text_editor-1.0.2] startup
# [3.092s] [ext: omni.kit.viewport.window-106.0.8] startup
# [3.115s] [ext: omni.kit.window.property-1.11.1] startup
# [3.117s] [ext: omni.usdphysics-106.0.20] startup
# [3.122s] [ext: omni.graph.tools-1.78.0] startup
# [3.148s] [ext: omni.kit.viewport.utility-1.0.17] startup
# [3.148s] [ext: omni.kit.property.usd-3.21.28] startup
# [3.159s] [ext: omni.graph-1.135.0] startup
# [3.213s] [ext: omni.graph.image.core-0.3.2] startup
# [3.219s] [ext: omni.graph.ui-1.70.0] startup
# [3.236s] [ext: omni.graph.action_core-1.1.4] startup
# [3.247s] [ext: omni.kit.window.cursor-1.1.2] startup
# [3.249s] [ext: omni.graph.image.nodes-1.0.2] startup
# [3.252s] [ext: omni.graph.action_nodes-1.23.0] startup
# [3.263s] [ext: omni.kit.viewport.menubar.core-106.0.2] startup
# [3.320s] [ext: omni.graph.nodes-1.143.0] startup
# [3.334s] [ext: omni.graph.action-1.102.1] startup
# [3.336s] [ext: omni.warp.core-1.2.1] startup
# [3.481s] [ext: omni.syntheticdata-0.6.7] startup
# [3.558s] [ext: omni.warp-1.2.1] startup
# [3.579s] [ext: omni.kvdb-106.0.20] startup
# [3.594s] [ext: omni.physx.foundation-106.0.20] startup
# [3.597s] [ext: omni.localcache-106.0.20] startup
# [3.606s] [ext: omni.convexdecomposition-106.0.20] startup
# [3.616s] [ext: omni.sensors.tiled-0.0.4] startup
# [3.621s] [ext: omni.physx.cooking-106.0.20] startup
# [3.650s] [ext: omni.kit.viewport.actions-106.0.3] startup
# [3.688s] [ext: omni.debugdraw-0.1.3] startup
# [3.710s] [ext: omni.physx-106.0.20] startup
# [3.741s] [ext: omni.kit.viewport.menubar.display-106.0.2] startup
# [3.770s] [ext: omni.kit.manipulator.transform-104.7.5] startup
# [3.807s] [ext: omni.kit.widget.toolbar-1.6.2] startup
# [3.926s] [ext: omni.physx.stageupdate-106.0.20] startup
# [3.929s] [ext: omni.usdphysics.ui-106.0.20] startup
# [3.963s] [ext: omni.physx.commands-106.0.20] startup
# [3.969s] [ext: omni.kit.manipulator.tool.snap-1.4.5] startup
# [3.976s] [ext: omni.kit.property.material-1.9.4] startup
# [3.980s] [ext: omni.physx.ui-106.0.20] startup
# [4.018s] [ext: omni.kit.manipulator.selector-1.1.1] startup
# [4.022s] [ext: omni.kit.widget.material_preview-1.0.16] startup
# [4.025s] [ext: omni.kit.manipulator.viewport-107.0.0] startup
# [4.027s] [ext: omni.kit.property.physx-106.0.20] startup
# [4.113s] [ext: omni.physx.demos-106.0.20] startup
# [4.137s] [ext: omni.kit.viewport.manipulator.transform-106.0.1] startup
# [4.140s] [ext: omni.kit.graph.delegate.default-1.2.2] startup
# [4.143s] [ext: omni.ui_query-1.1.2] startup
# [4.144s] [ext: omni.fabric.commands-1.1.4] startup
# [4.152s] [ext: omni.physx.vehicle-106.0.20] startup
# [4.174s] [ext: omni.kit.manipulator.prim.core-107.0.3] startup
# [4.185s] [ext: omni.kit.graph.editor.core-1.5.3] startup
# [4.189s] [ext: omni.kit.ui_test-1.2.18] startup
# [4.191s] [ext: omni.kit.graph.usd.commands-1.3.1] startup
# [4.193s] [ext: omni.physx.camera-106.0.20] startup
# [4.206s] [ext: omni.kit.manipulator.prim.fabric-106.0.1] startup
# [4.209s] [ext: omni.kit.manipulator.prim.usd-106.0.1] startup
# [4.212s] [ext: omni.physx.cct-106.0.20] startup
# [4.226s] [ext: omni.physics.tensors-106.0.20] startup
# [4.237s] [ext: omni.isaac.version-1.1.0] startup
# [4.239s] [ext: omni.kit.manipulator.selection-104.0.9] startup
# [4.242s] [ext: omni.kit.manipulator.prim-106.0.0] startup
# [4.242s] [ext: omni.command.usd-1.0.3] startup
# [4.245s] [ext: omni.physx.tensors-106.0.20] startup
# [4.254s] [ext: omni.isaac.nucleus-0.3.0] startup
# [4.255s] [ext: omni.kit.window.toolbar-1.6.1] startup
# [4.258s] [ext: omni.kit.widget.layers-1.7.9] startup
# [4.272s] [ext: omni.physx.graph-106.0.20] startup
# [4.292s] [ext: omni.physx.supportui-106.0.20] startup
# [4.318s] [ext: omni.physx.telemetry-106.0.20] startup
# [4.325s] [ext: omni.graph.scriptnode-1.19.1] startup
# [4.328s] [ext: omni.graph.ui_nodes-1.25.1] startup
# [4.340s] [ext: omni.kit.numpy.common-0.1.2] startup
# [4.344s] [ext: omni.physx.bundle-106.0.20] startup
# [4.346s] [ext: omni.kit.window.material_graph-1.8.15] startup
# [4.397s] [ext: omni.graph.bundle.action-2.0.4] startup
# [4.401s] [ext: omni.isaac.dynamic_control-1.3.8] startup
# [4.414s] [ext: omni.replicator.core-1.11.14] startup
# [4.646s] [ext: omni.isaac.core-3.18.1] startup
# [6.251s] [ext: omni.graph.visualization.nodes-2.1.1] startup
# [6.262s] [ext: omni.isaac.core_nodes-1.16.1] startup
# [6.280s] [ext: omni.isaac.cloner-0.8.1] startup
# [6.286s] [ext: omni.isaac.ui-0.16.0] startup
# [6.297s] [ext: omni.kit.graph.widget.variables-2.1.0] startup
# [6.303s] [ext: omni.kit.graph.delegate.modern-1.10.6] startup
# [6.309s] [ext: omni.isaac.wheeled_robots-2.3.3] startup
# [6.326s] [ext: omni.isaac.gym-0.11.3] startup
# [6.332s] [ext: omni.graph.window.core-1.109.0] startup
# [6.365s] [ext: omni.isaac.debug_draw-1.1.0] startup
# [6.377s] [ext: omni.isaac.block_world-1.0.0] startup
# [6.383s] [ext: omni.graph.window.generic-1.24.0] startup
# [6.407s] [ext: omni.isaac.menu-0.5.0] startup
# [6.416s] [ext: omni.isaac.occupancy_map-1.0.2] startup
# [6.425s] [ext: omni.importer.mjcf-1.1.1] startup
# [6.438s] [ext: omni.graph.window.action-1.26.0] startup
# [6.449s] [ext: omni.kit.widget.live-2.1.6] startup
# [6.453s] [ext: omni.kit.actions.window-1.1.1] startup
# [6.458s] [ext: omni.kit.ui.actions-1.0.1] startup
# [6.460s] [ext: omni.kit.widget.cache_indicator-2.0.8] startup
# [6.525s] [ext: omni.kit.hotkeys.window-1.4.5] startup
# [6.533s] [ext: omni.kit.selection-0.1.4] startup
# [6.536s] [ext: omni.kit.menu.common-1.1.5] startup
# [6.538s] [ext: omni.sensors.nv.common-1.2.2-isaac] startup
# [6.551s] [ext: omni.isaac.kit-1.13.0] startup
# [6.552s] [ext: omni.kit.menu.edit-1.1.24] startup
# [6.556s] [ext: omni.kit.menu.file-1.1.10] startup
# [6.559s] [ext: omni.isaac.range_sensor-3.1.1] startup
# [6.577s] [ext: omni.sensors.nv.materials-1.2.1-isaac] startup
# [6.580s] [ext: omni.kit.property.audio-1.0.11] startup
# [6.587s] [ext: omni.kit.widget.stage_icons-1.0.4] startup
# [6.590s] [ext: omni.kit.property.geometry-1.3.0] startup
# [6.594s] [ext: omni.kit.property.camera-1.0.6] startup
# [6.597s] [ext: omni.sensors.nv.lidar-1.2.2-isaac] startup
# [6.604s] [ext: omni.sensors.nv.wpm-1.2.1-isaac] startup
# [6.605s] [ext: omni.hydra.scene_api-0.1.2] startup
# [6.617s] [ext: omni.kit.window.stage-2.5.10] startup
# [6.622s] [ext: omni.kit.property.render-1.1.1] startup
# [6.624s] [ext: omni.kit.property.light-1.0.8] startup
# [6.627s] [ext: omni.sensors.nv.radar-1.2.1-isaac] startup
# [6.635s] [ext: omni.kit.property.transform-1.5.1] startup
# [6.641s] [ext: omni.kit.menu.stage-1.2.5] startup
# [6.644s] [ext: omni.kit.profiler.window-2.2.1] startup
# [6.654s] [ext: omni.kit.property.bundle-1.2.11] startup
# [6.658s] [ext: omni.kit.property.isaac-0.2.3] startup
# [6.661s] [ext: omni.isaac.sensor-12.7.1] startup
# [6.767s] [ext: omni.isaac.surface_gripper-1.0.1] startup
# [6.778s] [ext: omni.kit.stage_column.payload-2.0.0] startup
# [6.788s] [ext: omni.kit.property.layer-1.1.6] startup
# [6.804s] [ext: omni.isaac.scene_blox-0.1.2] startup
# [6.808s] [ext: omni.isaac.quadruped-1.4.5] startup
# [6.841s] [ext: omni.isaac.manipulators-2.1.0] startup
# [6.852s] [ext: omni.isaac.lula-3.0.1] startup
# [6.865s] [ext: omni.kit.viewport.menubar.render-106.1.3] startup
# [6.873s] [ext: omni.kit.viewport.menubar.settings-106.0.1] startup
# [6.886s] [ext: omni.kit.viewport.menubar.camera-105.1.8] startup
# [6.893s] [ext: omni.kit.manipulator.camera-105.0.5] startup
# [6.898s] [ext: omni.isaac.motion_generation-7.1.0] startup
# [6.905s] [ext: omni.kit.widget.calendar-1.0.8] startup
# [6.909s] [ext: omni.kit.stage_column.variant-1.0.13] startup
# [6.911s] [ext: omni.kit.viewport.bundle-104.0.1] startup
# [6.911s] [ext: omni.isaac.universal_robots-0.3.5] startup
# [6.912s] [ext: omni.kit.widget.extended_searchfield-1.0.28] startup
# [6.928s] [ext: omni.kit.widget.timeline-105.0.1] startup
# [6.934s] [ext: omni.kit.window.commands-0.2.5] startup
# [6.937s] [ext: omni.kit.window.console-0.2.12] startup
# [6.950s] [ext: omni.kit.window.script_editor-1.7.6] startup
# [6.953s] [ext: omni.kit.menu.create-1.0.13] startup
# [6.956s] [ext: omni.kit.window.status_bar-0.1.6] startup
# [6.963s] [ext: omni.rtx.window.settings-0.6.16] startup
# [6.969s] [ext: omni.isaac.franka-0.4.1] startup
# [6.972s] [ext: omni.kit.window.title-1.1.3] startup
# [6.979s] [ext: omni.replicator.isaac-1.15.0] startup
# [7.000s] [ext: omni.replicator.replicator_yaml-2.0.5] startup
# [7.034s] [ext: omni.rtx.settings.core-0.6.0] startup
# [7.044s] [ext: omni.isaac.cortex-0.3.8] startup
# [7.047s] [ext: omni.kit.viewport.menubar.lighting-106.0.2] startup
# [7.060s] [ext: semantics.schema.editor-0.3.6] startup
# [7.071s] [ext: semantics.schema.property-1.0.3] startup
# [7.077s] [ext: omni.kit.viewport.rtx-104.0.1] startup
# [7.077s] [ext: omni.isaac.utils-1.0.1] startup
# [7.082s] [ext: omni.isaac.cortex.sample_behaviors-1.0.5] startup
# [7.086s] [ext: omni.importer.urdf-1.14.1] startup
# [7.150s] [ext: omni.kit.window.stats-0.1.6] startup
# [7.158s] [ext: omni.isaac.sim.python-4.1.0] startup
# [7.164s] Simulation App Starting
# [9.352s] app ready

# %%
import os
import glob
import json

import carb
import omni
from pxr import Gf, Sdf
import omni.graph.core as og
import omni.replicator.core as rep
from omni.isaac.core import SimulationContext
from omni.isaac.core.objects import *
from omni.isaac.sensor import *
from omni.isaac.core.utils.stage import *
from omni.isaac.core.utils.prims import *
from omni.isaac.core.utils.viewports import *
from omni.isaac.core.utils.xforms import get_world_pose
from omni.isaac.nucleus import get_assets_root_path
import numpy as np

from rotations import *
from dimenvue import make_dimenvue

# %% [markdown]
# # 3. Capture LiDAR-RGB sample
# ## 3.1. Setup simulation
# The simulation stage set up as follow:
# - Build the dimenvue device
# - Put some object to for camera to see
# - Put some light to make object visible

# %%
def setup_scene(wall_size, cell_size=1.0, dt=1.0/30):
    create_new_stage()
    
    ctx = SimulationContext(physics_dt=dt, rendering_dt=dt)
    
    h = w = int(wall_size / cell_size)
    # stack a wall of cubes with different colors on YZ plane
    wall = create_prim(
        prim_path = '/wall'
    )
    
    colors = np.random.rand(h, w, 3)
    for i in range(h):
        for j in range(w):
            FixedCuboid(
                f'/wall/cube_{i}_{j}',
                translation=[0, cell_size*i, cell_size*j],
                size=cell_size,
                color=np.array(colors[i, j])
            )

    FixedCone('/cone',
              position = [-12, 12, 0],
              radius = 5.0,
              height=8.0, 
              color=np.array([1, 0, 0]))
    
    FixedCylinder('/cylinder',
                  position = [-12, -12, 0],
                  radius = 4.0,
                  height=10.0,
                  color = np.array([0, 1, 0]))
    
    create_prim(
        prim_path='/environment/light',
        prim_type="SphereLight",
        position=[0, 0, 0],
        attributes={
            "inputs:radius": 0.5,
            "inputs:intensity": 300000
        }
    )
    
    dimenvue = make_dimenvue(dimenvue_config)
    
    return ctx, wall, dimenvue

# %% [markdown]
# ## 3.3. Define test

# %%
import numpy as np
import copy

def capture_lidar_rgb(wall_size, cell_size=1.0, wall_distance=10):
    ctx, wall, dimenvue = setup_scene(wall_size, cell_size)
    wall.GetAttribute('xformOp:translate').Set(Gf.Vec3d(wall_distance, -wall_size/2, -wall_size/2))
    
    lidar = dimenvue['lidar']
    # lidar.enable_visualization()
    cameras = dimenvue['cameras']
    chassis = dimenvue['chassis']
    
    data = {
        'lidar': None,
        'cameras': {}
    }
    
    def log_points(lidar_data):
        data['lidar'] = copy.deepcopy(lidar_data)
        
    lidar.set_frame_ready_callback(log_points)

    ctx.play()
    for _ in range(30):
        ctx.step()
    ctx.stop()
    
    for cam in cameras:
        data['cameras'][str(cam.prim_path).split('/')[-1]] = cam.get_rgba()
    
    return data

# %% [markdown]
# ## 3.4. Run tests

# %%
data = capture_lidar_rgb(wall_size, cell_size, wall_distance)

# %%
resume_gui()
# Out:
# gui can be used now. interrupt kernel to go back to notebook

# %% [markdown]
# # 4. Align Lidar and RGB
# ## 4.1. Save sim data for later

# %%
import pickle

with open(PICKLE_FILE, 'wb') as f:
    pickle.dump(data, f)

# %% [markdown]
# ## 4.2. Reload data
# Run cell in section 0 first to set parameters

# %%
# run
import pickle

with open(PICKLE_FILE, 'rb') as f:
    data = pickle.load(f)

# %% [markdown]
# ## 4.3. Log to rerun for visualization

# %%
import rerun as rr
import numpy as np

rr.init('test_lidar_rgb', spawn=True)
# Out:
# [2024-09-06T04:40:34Z INFO  re_sdk_comms::server] Hosting a SDK server over TCP at 0.0.0.0:9876. Connect with the Rerun logging SDK.
# [2024-09-06T04:40:34Z INFO  winit::platform_impl::platform::x11::window] Guessed window scale factor: 1
# [2024-09-06T04:40:34Z INFO  re_sdk_comms::server] New SDK client connected from: 127.0.0.1:58850
# [2024-09-06T04:40:34Z WARN  wgpu_hal::gles::egl] No config found!
# [2024-09-06T04:40:34Z WARN  wgpu_hal::gles::egl] EGL says it can present to the window but not natively
# [2024-09-06T04:40:34Z INFO  egui_wgpu] There were 3 available wgpu adapters: {backend: Vulkan, device_type: Cpu, name: "llvmpipe (LLVM 12.0.0, 256 bits)", driver: "llvmpipe", driver_info: "Mesa 21.2.6 (LLVM 12.0.0)", vendor: 0x10005}, {backend: Vulkan, device_type: DiscreteGpu, name: "NVIDIA GeForce RTX 4060", driver: "NVIDIA", driver_info: "555.42.02", vendor: 0x10DE, device: 0x2882}, {backend: Gl, device_type: Other, name: "NVIDIA GeForce RTX 4060/PCIe/SSE2", driver: "OpenGL", driver_info: "4.6.0 NVIDIA 555.42.02", vendor: 0x10DE}

# %%
"""
Args:
    pos: translation
    ori: [rx, ry, rz] rotation around parent xyz axes in degrees (extrinsic convention)
"""
def rr_transform(pos:np.ndarray, ori:np.ndarray):
    wxyz = euler_angles_to_quat(ori, degrees=True, extrinsic=True)
    xyzw = np.roll(wxyz, -1)
    return rr.Transform3D(
        translation=pos,
        quaternion=xyzw
    )

def Axes(length=1.0):
    return rr.Arrows3D(
        vectors=[[length, 0, 0], [0, length, 0], [0, 0, length]],
        colors=[[255,0,0], [0,255,0], [0,0,255]],
    )

# %%
import rotations

def rr_transform(pos:np.ndarray, ori:np.ndarray):
    wxyz = euler_angles_to_quat(ori, degrees=True, extrinsic=True)
    xyzw = np.roll(wxyz, -1)
    return rr.Transform3D(
        translation=pos,
        quaternion=xyzw
    )

def rr_set_up_frame():
    rr.set_time_seconds('sim_time', 0.0)
    rr.log('/world', rr.Clear(recursive=True))
    rr.log('/world', Axes(1), static=True)
    rr.log('/world/chassis', Axes(1))
    if 'lidar' in dimenvue_config:
        c = dimenvue_config['lidar']
        p, r = c['chassis_lidar_translate'], c['chassis_lidar_rotate']
        rr.log('/world/chassis/lidar', rr_transform(p, r))
        rr.log('/world/chassis/lidar', Axes(1))
    if 'cameras' in dimenvue_config:
        c = dimenvue_config['cameras']
        p, r = c['chassis_cameras_translate'], c['chassis_cameras_rotate']
        rr.log('/world/chassis/cameras', rr_transform(p, r))
        for i in range(c['n_cameras']):
            p, r = c['camera_translate'][i], c['camera_rotate'][i]
            rr.log(f'/world/chassis/cameras/cam{i}', rr_transform(p, r))
            rr.log(f'/world/chassis/cameras/cam{i}', Axes(1))
            c1 = c['calibrate_config']
            ((fx, _, cx),(_,fy,cy),(_,_,_)) = c1['camera_intrinsics']
            rr.log(f'/world/chassis/cameras/cam{i}/image', rr.Pinhole(
                resolution=c1['camera_resolution'],
                camera_xyz=rr.ViewCoordinates.RDF, #same as ROS
                focal_length=(fx, fy),
                principal_point=(cx, cy),
                image_plane_distance=wall_distance - cell_size/2 - ring_R
            ))

rr_set_up_frame()

# %%
def tf(translate, rotate):
    tf = np.eye(4)
    tf[:3, 3] = translate
    tf[:3, :3] = euler_to_rot_matrix(rotate, degrees=True, extrinsic=True)
    return tf

def get_transforms(config):
    c = config['lidar']
    p, r = c['chassis_lidar_translate'], c['chassis_lidar_rotate']
    tf_chassis_lidar = tf(p, r)
    c = config['cameras']
    p, r = c['chassis_cameras_translate'], c['chassis_cameras_rotate']
    tf_chassis_cameras = tf(p, r)
    tf_camera_lidar = []
    for i in range(c['n_cameras']):
        p, r = c['camera_translate'][i], c['camera_rotate'][i]
        tf_chassis_camera_i = np.dot(tf_chassis_cameras, tf(p, r))
        tf_camera_i_chassis = np.linalg.inv(tf_chassis_camera_i)
        tf_camera_i_lidar = np.dot(tf_camera_i_chassis, tf_chassis_lidar)
        tf_camera_lidar.append(tf_camera_i_lidar)
    
    return tf_camera_lidar        


tf_camera_lidar = get_transforms(dimenvue_config)

def to_frame(points, tf):
    return np.dot(tf[:3, :3], points.T).T + tf[:3, 3]

# %%
intrinsic = dimenvue_config['cameras']['calibrate_config']['camera_intrinsics']
points = data['lidar']['point_cloud_data']
rgb = data['cameras']['cam0']
tf = tf_camera_lidar[0]

def colorize(points, rgb, intrinsic, tf):
    ((fx, _, cx),(_,fy,cy),(_,_,_)) = intrinsic
    w, h = cx*2, cy*2
    # move points from lidar frame to camera frame
    points_cam = to_frame(points, tf)
    # remove the points behind the camera
    front_points_idx = np.where(points_cam[:, 2] > 0)[0]
    front_points = points_cam[front_points_idx]
    # x = x/z, y = y/z, z = 1
    points_xy = front_points / front_points[:, 2][:, None]
    # project to image plane
    u = points_xy[:, 0] * fx + cx
    v = points_xy[:, 1] * fy + cy
    u = np.round(u).astype(int)
    v = np.round(v).astype(int)

    inframe_points_idx = np.where((u >= 0) & (u < w) & (v >= 0) & (v < h))[0]
    u = u[inframe_points_idx]
    v = v[inframe_points_idx]
    colors = rgb[v, u]

    points_idx = front_points_idx[inframe_points_idx]
    colored_points = points[points_idx]

    return colored_points, colors, points_idx

color_points, colors, idx = colorize(points, rgb, intrinsic, tf)
rr.log('/world/chassis/lidar/points_color', rr.Points3D(
    positions=color_points, 
    colors=colors)
)

# %%
intrinsic = dimenvue_config['cameras']['calibrate_config']['camera_intrinsics']
n_cams = dimenvue_config['cameras']['n_cameras']
points = data['lidar']['point_cloud_data']
rr.log('/world/chassis/lidar/points', rr.Points3D(positions=points))
result_points = []
result_colors = []
for i in range(n_cams):
    rgb = data['cameras'][f'cam{i}']
    rr.log(f'/world/chassis/cameras/cam{i}/image', rr.Image(rgb))
    tf = tf_camera_lidar[i]
    color_points, colors, idx = colorize(points, rgb, intrinsic, tf_camera_lidar[i])
    result_points.append(color_points)
    result_colors.append(colors)
    points = np.delete(points, idx, axis=0)

points = np.concatenate(result_points)
colors = np.concatenate(result_colors)
rr.log(f'/world/chassis/lidar/points_color', rr.Points3D(
    positions=points, 
    colors=colors)
)

# %%
resume_gui()
# Out:
# gui can be used now. interrupt kernel to go back to notebook
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# Canceled future for execute_request message before replies were done
