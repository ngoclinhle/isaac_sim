# %% [markdown]
# # 1. Start Isaac

# %%
import sys
import os
import signal

from isaacsim import SimulationApp

CONFIG = {
  'headless': True,
  'display_options': 3286
}

# Example for creating a RTX lidar sensor and publishing PointCloud2 data
simulation_app = SimulationApp(CONFIG)
simulation_app.update()

spinning = True
def sigint_handler(sig, frame):
  global spinning
  spinning = False
signal.signal(signal.SIGINT, sigint_handler)

kernel = get_ipython().kernel
kernel.pre_handler_hook = lambda: None
kernel.post_handler_hook = lambda: None

def spin(update_function, *args, **kwargs):
  global spinning
  print('gui can be used now. interrupt kernel to go back to notebook')
  while spinning:
    update_function(*args, **kwargs)
  spinning = True

def resume_gui():
  spin(lambda: simulation_app.update())
  
if CONFIG['headless']:
  del spin
  del resume_gui
  

print('workdir:', os.getcwd())
# Out:
# Starting kit application with the following args:  ['/f/ov/pkg/isaac-sim-4.1.0/exts/omni.isaac.kit/omni/isaac/kit/simulation_app.py', '/f/ov/pkg/isaac-sim-4.1.0/apps/omni.isaac.sim.python.kit', '--/app/tokens/exe-path=/f/ov/pkg/isaac-sim-4.1.0/kit', '--/persistent/app/viewport/displayOptions=3286', '--/rtx/materialDb/syncLoads=True', '--/rtx/hydra/materialSyncLoads=True', '--/omni.kit.plugin/syncUsdLoads=True', '--/app/renderer/resolution/width=1280', '--/app/renderer/resolution/height=720', '--/app/window/width=1440', '--/app/window/height=900', '--/renderer/multiGpu/enabled=True', '--/app/fastShutdown=False', '--ext-folder', '/f/ov/pkg/isaac-sim-4.1.0/exts', '--ext-folder', '/f/ov/pkg/isaac-sim-4.1.0/apps', '--/physics/cudaDevice=0', '--portable', '--no-window', '--/app/window/hideUi=1']
# Passing the following args to the base kit application:  ['-f', '/home/linh/.local/share/jupyter/runtime/kernel-7239753a-3294-47e6-8a88-feab89dba6dc.json']
# [Warning] [omni.isaac.kit.simulation_app] fast shutdown not supported with jupyter notebooks
# [0.067s] [ext: omni.kit.async_engine-0.0.0] startup
# [0.482s] [ext: omni.stats-1.0.1] startup
# [0.483s] [ext: omni.client-1.1.0] startup
# [0.515s] [ext: omni.datastore-0.0.0] startup
# [0.516s] [ext: omni.blobkey-1.1.0] startup
# [0.516s] [ext: omni.ujitso.default-1.0.0] startup
# [0.517s] [ext: omni.hsscclient-0.0.0] startup
# [0.517s] [ext: omni.rtx.shadercache.vulkan-1.0.0] startup
# [0.518s] [ext: omni.assets.plugins-0.0.0] startup
# [0.519s] [ext: omni.gpu_foundation-0.0.0] startup
# [0.527s] [ext: carb.windowing.plugins-1.0.0] startup
# [0.535s] [ext: omni.kit.renderer.init-0.0.0] startup
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 555.42.02     | Graphics API: Vulkan
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 4060          | Yes: 0 |     | 8434    MB | 10de      | 0          |
# |     |                                  |        |     |            | 2882      | 82fb92c9.. |
# |     |                                  |        |     |            | 1         |            |
# |=============================================================================================|
# | OS: 20.04.6 LTS (Focal Fossa) ubuntu, Version: 20.04.6, Kernel: 5.15.0-125-generic
# | XServer Vendor: The X.Org Foundation, XServer Version: 12013000 (1.20.13.0)
# | Processor: Intel(R) Core(TM) i9-10900K CPU @ 3.70GHz | Cores: 10 | Logical: 20
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 64148 | Free Memory: 49949
# | Total Page/Swap (MB): 1899 | Free Page/Swap: 2
# |---------------------------------------------------------------------------------------------|
# [1.494s] [ext: omni.kit.pipapi-0.0.0] startup
# [1.495s] [ext: omni.kit.pip_archive-0.0.0] startup
# [1.496s] [ext: omni.pip.compute-1.4.0] startup
# [1.496s] [ext: omni.kit.telemetry-0.5.0] startup
# [1.516s] [ext: omni.pip.cloud-1.1.3] startup
# [1.519s] [ext: omni.isaac.core_archive-2.3.0] startup
# [1.519s] [ext: omni.mtlx-0.1.0] startup
# [1.520s] [ext: omni.usd.config-1.0.4] startup
# [1.524s] [ext: omni.gpucompute.plugins-0.0.0] startup
# [1.525s] [ext: omni.usd.libs-1.0.1] startup
# [1.630s] [ext: omni.isaac.ml_archive-2.0.1] startup
# [1.631s] [ext: omni.kit.loop-isaac-1.2.0] startup
# [1.631s] [ext: omni.kit.test-0.0.0] startup
# [1.664s] [ext: omni.appwindow-1.1.8] startup
# [1.665s] [ext: omni.kit.renderer.core-1.0.1] startup
# [1.689s] [ext: omni.kit.renderer.capture-0.0.0] startup
# [1.691s] [ext: omni.kit.renderer.imgui-1.0.1] startup
# [1.781s] [ext: omni.ui-2.23.11] startup
# [1.793s] [ext: omni.kit.mainwindow-1.0.3] startup
# [1.794s] [ext: carb.audio-0.1.0] startup
# [1.816s] [ext: omni.uiaudio-1.0.0] startup
# [1.817s] [ext: omni.kit.uiapp-0.0.0] startup
# [1.817s] [ext: omni.usd.schema.geospatial-0.0.0] startup
# [1.916s] [ext: omni.anim.navigation.schema-106.0.2] startup
# [1.931s] [ext: omni.usd.schema.audio-0.0.0] startup
# [1.934s] [ext: omni.usd.schema.semantics-0.0.0] startup
# [1.942s] [ext: omni.usd.schema.anim-0.0.0] startup
# [1.960s] [ext: omni.usd.schema.omnigraph-1.0.0] startup
# [1.967s] [ext: omni.usd.schema.isaac-2.1.0] startup
# [1.975s] [ext: omni.usd.schema.scene.visualization-2.0.2] startup
# [1.977s] [ext: omni.usd.schema.physx-106.0.20] startup
# [2.024s] [ext: omni.usd.schema.omniscripting-1.0.0] startup
# [2.029s] [ext: omni.anim.graph.schema-106.0.2] startup
# [2.036s] [ext: omni.usd.schema.forcefield-106.0.20] startup
# [2.043s] [ext: omni.kit.window.popup_dialog-2.0.24] startup
# [2.047s] [ext: omni.graph.exec-0.9.3] startup
# [2.048s] [ext: omni.kit.widget.nucleus_connector-1.1.8] startup
# [2.051s] [ext: omni.kit.usd_undo-0.1.8] startup
# [2.051s] [ext: omni.kit.exec.core-0.13.2] startup
# [2.053s] [ext: omni.usd_resolver-1.0.0] startup
# [2.058s] [ext: omni.resourcemonitor-105.0.1] startup
# [2.060s] [ext: omni.kit.actions.core-1.0.0] startup
# [2.061s] [ext: omni.activity.core-1.0.1] startup
# [2.063s] [ext: omni.usd.core-1.2.11] startup
# [2.068s] [ext: omni.timeline-1.0.10] startup
# [2.069s] [ext: omni.kit.commands-1.4.9] startup
# [2.073s] [ext: usdrt.scenegraph-7.4.8] startup
# [2.125s] [ext: omni.kit.audiodeviceenum-1.0.1] startup
# [2.126s] [ext: omni.hydra.usdrt_delegate-7.4.7] startup
# [2.152s] [ext: omni.hydra.scene_delegate-0.3.3] startup
# [2.161s] [ext: omni.usd-1.11.2] startup
# [2.215s] [ext: omni.kit.notification_manager-1.0.8] startup
# [2.217s] [ext: omni.kit.clipboard-1.0.3] startup
# [2.218s] [ext: omni.kit.widget.path_field-2.0.9] startup
# [2.218s] [ext: omni.kit.collaboration.telemetry-1.0.0] startup
# [2.219s] [ext: omni.kit.helper.file_utils-0.1.8] startup
# [2.221s] [ext: omni.kit.widget.nucleus_info-1.0.2] startup
# [2.222s] [ext: omni.kit.widget.context_menu-1.2.1] startup
# [2.223s] [ext: omni.kit.widget.browser_bar-2.0.10] startup
# [2.224s] [ext: omni.kit.collaboration.channel_manager-1.0.11] startup
# [2.225s] [ext: omni.kit.widget.filebrowser-2.10.48] startup
# [2.229s] [ext: omni.kit.search_core-1.0.5] startup
# [2.230s] [ext: omni.kit.widget.options_menu-1.1.4] startup
# [2.233s] [ext: omni.kit.widget.searchable_combobox-1.0.6] startup
# [2.234s] [ext: omni.kit.widget.search_delegate-1.0.4] startup
# [2.235s] [ext: omni.ui.scene-1.9.3] startup
# [2.241s] [ext: omni.kit.widget.options_button-1.0.2] startup
# [2.241s] [ext: omni.kit.widget.settings-1.1.1] startup
# [2.243s] [ext: omni.kit.menu.utils-1.5.27] startup
# [2.258s] [ext: omni.kit.window.filepicker-2.10.34] startup
# [2.266s] [ext: omni.kit.widget.prompt-1.0.7] startup
# [2.267s] [ext: omni.kit.usd.layers-2.1.31] startup
# [2.278s] [ext: omni.kit.window.preferences-1.5.3] startup
# [2.286s] [ext: omni.kit.widget.live_session_management.ui-1.0.1] startup
# [2.289s] [ext: omni.kit.collaboration.presence_layer-1.0.8] startup
# [2.292s] [ext: omni.kit.widget.live_session_management-1.2.18] startup
# [2.294s] [ext: omni.inspect-1.0.1] startup
# [2.296s] [ext: omni.kit.widget.graph-1.12.8] startup
# [2.301s] [ext: omni.kit.widget.filter-1.1.4] startup
# [2.302s] [ext: omni.graph.core-2.170.3] startup
# [2.306s] [ext: omni.kit.window.extensions-1.4.9] startup
# [2.312s] [ext: omni.kit.hotkeys.core-1.3.3] startup
# [2.313s] [ext: omni.kit.context_menu-1.8.0] startup
# [2.314s] [ext: omni.mdl-52.0.1] startup
# [2.336s] [ext: omni.iray.libs-0.0.0] startup
# [2.341s] [ext: omni.kit.primitive.mesh-1.0.16] startup
# [2.344s] [ext: omni.kit.stage_template.core-1.1.21] startup
# [2.345s] [ext: omni.mdl.neuraylib-0.2.5] startup
# [2.346s] [ext: omni.ujitso.processor.texture-1.0.0] startup
# [2.347s] [ext: omni.kit.window.file_exporter-1.0.29] startup
# [2.349s] [ext: omni.kit.stage_templates-1.2.3] startup
# [2.351s] [ext: omni.volume-0.5.0] startup
# [2.354s] [ext: omni.ujitso.client-0.0.0] startup
# [2.354s] [ext: omni.kit.window.file_importer-1.1.11] startup
# [2.355s] [ext: omni.kit.window.drop_support-1.0.2] startup
# [2.356s] [ext: omni.kit.window.file-1.3.52] startup
# [2.359s] [ext: omni.kit.window.content_browser_registry-0.0.6] startup
# [2.360s] [ext: omni.hydra.rtx-0.2.0] startup
# [2.378s] [ext: omni.kit.widget.highlight_label-1.0.2] startup
# [2.378s] [ext: omni.kit.window.content_browser-2.9.14] startup
# [2.396s] [ext: omni.kit.widget.stage-2.10.26] startup
# [2.407s] [ext: omni.kit.material.library-1.4.4] startup
# [2.414s] [ext: omni.kit.hydra_texture-1.2.6] startup
# [2.421s] [ext: omni.kit.viewport.legacy_gizmos-1.0.15] startup
# [2.426s] [ext: omni.kit.raycast.query-1.0.5] startup
# [2.436s] [ext: omni.hydra.engine.stats-1.0.2] startup
# [2.441s] [ext: omni.kit.widget.searchfield-1.1.6] startup
# [2.443s] [ext: omni.kit.widget.viewport-106.0.3] startup
# [2.447s] [ext: omni.kit.viewport.registry-104.0.6] startup
# [2.448s] [ext: omni.kit.widget.text_editor-1.0.2] startup
# [2.449s] [ext: omni.kit.viewport.window-106.0.8]
# Warning: Possible version incompatibility. Attempting to load omni::fabric::IPath with version v0.2 against v0.1.
# Warning: Possible version incompatibility. Attempting to load omni::fabric::IPath with version v0.2 against v0.1.
# Warp 1.2.1 initialized:
#    CUDA Toolkit 11.8, Driver 12.5
#    Devices:
#      "cpu"      : "x86_64"
#      "cuda:0"   : "NVIDIA GeForce RTX 4060" (8 GiB, sm_89, mempool enabled)
#    Kernel cache:
#      /home/linh/.cache/warp/1.2.1
# startup
# [2.472s] [ext: omni.kit.window.property-1.11.1] startup
# [2.474s] [ext: omni.usdphysics-106.0.20] startup
# [2.479s] [ext: omni.graph.tools-1.78.0] startup
# [2.502s] [ext: omni.kit.viewport.utility-1.0.17] startup
# [2.503s] [ext: omni.kit.property.usd-3.21.28] startup
# [2.513s] [ext: omni.graph-1.135.0] startup
# [2.641s] [ext: omni.graph.image.core-0.3.2] startup
# [2.648s] [ext: omni.graph.ui-1.70.0] startup
# [2.671s] [ext: omni.graph.action_core-1.1.4] startup
# [2.686s] [ext: omni.kit.window.cursor-1.1.2] startup
# [2.688s] [ext: omni.graph.image.nodes-1.0.2] startup
# [2.691s] [ext: omni.graph.action_nodes-1.23.0] startup
# [2.701s] [ext: omni.kit.viewport.menubar.core-106.0.2] startup
# [2.731s] [ext: omni.graph.nodes-1.143.0] startup
# [2.754s] [ext: omni.graph.action-1.102.1] startup
# [2.763s] [ext: omni.warp.core-1.2.1] startup
# [2.898s] [ext: omni.syntheticdata-0.6.7] startup
# [2.972s] [ext: omni.warp-1.2.1] startup
# [2.984s] [ext: omni.kvdb-106.0.20] startup
# [2.994s] [ext: omni.physx.foundation-106.0.20] startup
# [2.995s] [ext: omni.localcache-106.0.20] startup
# [3.000s] [ext: omni.convexdecomposition-106.0.20] startup
# [3.012s] [ext: omni.sensors.tiled-0.0.4] startup
# [3.017s] [ext: omni.physx.cooking-106.0.20] startup
# [3.036s] [ext: omni.kit.viewport.actions-106.0.3] startup
# [3.047s] [ext: omni.debugdraw-0.1.3] startup
# [3.060s] [ext: omni.physx-106.0.20] startup
# [3.087s] [ext: omni.kit.viewport.menubar.display-106.0.2] startup
# [3.117s] [ext: omni.kit.manipulator.transform-104.7.5] startup
# [3.139s] [ext: omni.kit.widget.toolbar-1.6.2] startup
# [3.300s] [ext: omni.physx.stageupdate-106.0.20] startup
# [3.324s] [ext: omni.usdphysics.ui-106.0.20] startup
# [3.356s] [ext: omni.physx.commands-106.0.20] startup
# [3.362s] [ext: omni.kit.manipulator.tool.snap-1.4.5] startup
# [3.369s] [ext: omni.kit.property.material-1.9.4] startup
# [3.373s] [ext: omni.physx.ui-106.0.20] startup
# [3.409s] [ext: omni.kit.manipulator.selector-1.1.1] startup
# [3.413s] [ext: omni.kit.widget.material_preview-1.0.16] startup
# [3.416s] [ext: omni.kit.manipulator.viewport-107.0.0] startup
# [3.418s] [ext: omni.kit.property.physx-106.0.20] startup
# [3.502s] [ext: omni.physx.demos-106.0.20] startup
# [3.525s] [ext: omni.kit.viewport.manipulator.transform-106.0.1] startup
# [3.529s] [ext: omni.kit.graph.delegate.default-1.2.2] startup
# [3.531s] [ext: omni.ui_query-1.1.2] startup
# [3.532s] [ext: omni.fabric.commands-1.1.4] startup
# [3.540s] [ext: omni.physx.vehicle-106.0.20] startup
# [3.561s] [ext: omni.kit.manipulator.prim.core-107.0.3] startup
# [3.571s] [ext: omni.kit.graph.editor.core-1.5.3] startup
# [3.575s] [ext: omni.kit.ui_test-1.2.18] startup
# [3.577s] [ext: omni.kit.graph.usd.commands-1.3.1] startup
# [3.578s] [ext: omni.physx.camera-106.0.20] startup
# [3.591s] [ext: omni.kit.manipulator.prim.fabric-106.0.1] startup
# [3.594s] [ext: omni.kit.manipulator.prim.usd-106.0.1] startup
# [3.597s] [ext: omni.physx.cct-106.0.20] startup
# [3.610s] [ext: omni.physics.tensors-106.0.20] startup
# [3.621s] [ext: omni.isaac.version-1.1.0] startup
# [3.624s] [ext: omni.kit.manipulator.selection-104.0.9] startup
# [3.629s] [ext: omni.kit.manipulator.prim-106.0.0] startup
# [3.629s] [ext: omni.command.usd-1.0.3] startup
# [3.631s] [ext: omni.physx.tensors-106.0.20] startup
# [3.638s] [ext: omni.isaac.nucleus-0.3.0] startup
# [3.639s] [ext: omni.kit.window.toolbar-1.6.1] startup
# [3.643s] [ext: omni.kit.widget.layers-1.7.9] startup
# [3.656s] [ext: omni.physx.graph-106.0.20] startup
# [3.675s] [ext: omni.physx.supportui-106.0.20] startup
# [3.700s] [ext: omni.physx.telemetry-106.0.20] startup
# [3.706s] [ext: omni.graph.scriptnode-1.19.1] startup
# [3.709s] [ext: omni.graph.ui_nodes-1.25.1] startup
# [3.718s] [ext: omni.kit.numpy.common-0.1.2] startup
# [3.724s] [ext: omni.physx.bundle-106.0.20] startup
# [3.726s] [ext: omni.kit.window.material_graph-1.8.15] startup
# [3.775s] [ext: omni.graph.bundle.action-2.0.4] startup
# [3.776s] [ext: omni.isaac.dynamic_control-1.3.8] startup
# [3.791s] [ext: omni.replicator.core-1.11.14] startup
# [4.020s] [ext: omni.isaac.core-3.18.1] startup
# [5.592s] [ext: omni.graph.visualization.nodes-2.1.1] startup
# [5.603s] [ext: omni.isaac.core_nodes-1.16.1] startup
# [5.621s] [ext: omni.isaac.cloner-0.8.1] startup
# [5.626s] [ext: omni.isaac.ui-0.16.0] startup
# [5.637s] [ext: omni.kit.graph.widget.variables-2.1.0] startup
# [5.642s] [ext: omni.kit.graph.delegate.modern-1.10.6] startup
# [5.650s] [ext: omni.isaac.wheeled_robots-2.3.3] startup
# [5.665s] [ext: omni.isaac.gym-0.11.3] startup
# [5.670s] [ext: omni.graph.window.core-1.109.0] startup
# [5.698s] [ext: omni.isaac.debug_draw-1.1.0] startup
# [5.708s] [ext: omni.isaac.block_world-1.0.0] startup
# [5.715s] [ext: omni.graph.window.generic-1.24.0] startup
# [5.734s] [ext: omni.isaac.menu-0.5.0] startup
# [5.744s] [ext: omni.isaac.occupancy_map-1.0.2] startup
# [5.752s] [ext: omni.importer.mjcf-1.1.1] startup
# [5.762s] [ext: omni.graph.window.action-1.26.0] startup
# [5.773s] [ext: omni.kit.widget.live-2.1.6] startup
# [5.777s] [ext: omni.kit.actions.window-1.1.1] startup
# [5.782s] [ext: omni.kit.ui.actions-1.0.1] startup
# [5.783s] [ext: omni.kit.widget.cache_indicator-2.0.8] startup
# [5.848s] [ext: omni.kit.hotkeys.window-1.4.5] startup
# [5.855s] [ext: omni.kit.selection-0.1.4] startup
# [5.857s] [ext: omni.kit.menu.common-1.1.5] startup
# [5.859s] [ext: omni.sensors.nv.common-1.2.2-isaac] startup
# [5.872s] [ext: omni.isaac.kit-1.13.0] startup
# [5.872s] [ext: omni.kit.menu.edit-1.1.24] startup
# [5.877s] [ext: omni.kit.menu.file-1.1.10] startup
# [5.880s] [ext: omni.isaac.range_sensor-3.1.1] startup
# [5.896s] [ext: omni.sensors.nv.materials-1.2.1-isaac] startup
# [5.899s] [ext: omni.kit.property.audio-1.0.11] startup
# [5.902s] [ext: omni.kit.widget.stage_icons-1.0.4] startup
# [5.905s] [ext: omni.kit.property.geometry-1.3.0] startup
# [5.912s] [ext: omni.kit.property.camera-1.0.6] startup
# [5.914s] [ext: omni.sensors.nv.lidar-1.2.2-isaac] startup
# [5.921s] [ext: omni.sensors.nv.wpm-1.2.1-isaac] startup
# [5.922s] [ext: omni.hydra.scene_api-0.1.2] startup
# [5.932s] [ext: omni.kit.window.stage-2.5.10] startup
# [5.937s] [ext: omni.kit.property.render-1.1.1] startup
# [5.939s] [ext: omni.kit.property.light-1.0.8] startup
# [5.941s] [ext: omni.sensors.nv.radar-1.2.1-isaac] startup
# [5.948s] [ext: omni.kit.property.transform-1.5.1] startup
# [5.954s] [ext: omni.kit.menu.stage-1.2.5] startup
# [5.956s] [ext: omni.kit.profiler.window-2.2.1] startup
# [5.965s] [ext: omni.kit.property.bundle-1.2.11] startup
# [5.969s] [ext: omni.kit.property.isaac-0.2.3] startup
# [5.972s] [ext: omni.isaac.sensor-12.7.1] startup
# [6.058s] [ext: omni.isaac.surface_gripper-1.0.1] startup
# [6.065s] [ext: omni.kit.stage_column.payload-2.0.0] startup
# [6.070s] [ext: omni.kit.property.layer-1.1.6] startup
# [6.078s] [ext: omni.isaac.scene_blox-0.1.2] startup
# [6.083s] [ext: omni.isaac.quadruped-1.4.5] startup
# [6.122s] [ext: omni.isaac.manipulators-2.1.0] startup
# [6.132s] [ext: omni.isaac.lula-3.0.1] startup
# [6.146s] [ext: omni.kit.viewport.menubar.render-106.1.3] startup
# [6.153s] [ext: omni.kit.viewport.menubar.settings-106.0.1] startup
# [6.165s] [ext: omni.kit.viewport.menubar.camera-105.1.8] startup
# [6.173s] [ext: omni.kit.manipulator.camera-105.0.5] startup
# [6.177s] [ext: omni.isaac.motion_generation-7.1.0] startup
# [6.183s] [ext: omni.kit.widget.calendar-1.0.8] startup
# [6.187s] [ext: omni.kit.stage_column.variant-1.0.13] startup
# [6.189s] [ext: omni.kit.viewport.bundle-104.0.1] startup
# [6.189s] [ext: omni.isaac.universal_robots-0.3.5] startup
# [6.191s] [ext: omni.kit.widget.extended_searchfield-1.0.28] startup
# [6.205s] [ext: omni.kit.widget.timeline-105.0.1] startup
# [6.210s] [ext: omni.kit.window.commands-0.2.5] startup
# [6.213s] [ext: omni.kit.window.console-0.2.12] startup
# [6.225s] [ext: omni.kit.window.script_editor-1.7.6] startup
# [6.227s] [ext: omni.kit.menu.create-1.0.13] startup
# [6.230s] [ext: omni.kit.window.status_bar-0.1.6] startup
# [6.236s] [ext: omni.rtx.window.settings-0.6.16] startup
# [6.241s] [ext: omni.isaac.franka-0.4.1] startup
# [6.243s] [ext: omni.kit.window.title-1.1.3] startup
# [6.249s] [ext: omni.replicator.isaac-1.15.0] startup
# [6.268s] [ext: omni.replicator.replicator_yaml-2.0.5] startup
# [6.296s] [ext: omni.rtx.settings.core-0.6.0] startup
# [6.305s] [ext: omni.isaac.cortex-0.3.8] startup
# [6.307s] [ext: omni.kit.viewport.menubar.lighting-106.0.2] startup
# [6.322s] [ext: semantics.schema.editor-0.3.6] startup
# [6.331s] [ext: semantics.schema.property-1.0.3] startup
# [6.335s] [ext: omni.kit.viewport.rtx-104.0.1] startup
# [6.335s] [ext: omni.isaac.utils-1.0.1] startup
# [6.341s] [ext: omni.isaac.cortex.sample_behaviors-1.0.5] startup
# [6.344s] [ext: omni.importer.urdf-1.14.1] startup
# [6.410s] [ext: omni.kit.window.stats-0.1.6] startup
# [6.416s] [ext: omni.isaac.sim.python-4.1.0] startup
# [6.424s] Simulation App Starting
# [8.516s] app ready
# workdir: /f/ov/pkg/isaac-sim-4.1.0/dimenvue_ws

# %%
import omni
from omni.isaac.core import World
from omni.isaac.core.utils.stage import *
from omni.isaac.core.objects import *
from omni.isaac.core.utils.rotations import *
from omni.isaac.core.utils.prims import *
from omni.isaac.core.utils.xforms import *
from omni.isaac.sensor import *
from omni.isaac.nucleus import *

from dimenvue import Dimenvue

# %% [markdown]
# # 3. Setup scene

# %%
def setup_sim():
    create_new_stage()    
    world = World(physics_dt=1.0/400, rendering_dt=1.0/10)
    asset_root = get_assets_root_path()
    office_uds_path = asset_root + "/Isaac/Environments/Office/office.usd"
    assert is_file(office_uds_path), "Office environment not found"
    add_reference_to_stage(office_uds_path, prim_path="/World/office")
    world.render()
    light = create_prim('/World/light', 'RectLight', translation=[0,0,2.97])
    light.GetAttribute('inputs:intensity').Set(1000.0)
    light.GetAttribute('inputs:height').Set(150.0)
    light.GetAttribute('inputs:width').Set(100.0)
    dimenvue = Dimenvue(
        config_filfe_name="dimenvue_config.json",
        prim_path="/world/dimenvue",
        name="dimenvue"    
    )
    world.scene.add(dimenvue)
    world.reset(soft=False)
    return world, dimenvue

# %% [markdown]
# # 4. Run sim and log data

# %%
from PIL import Image
import numpy as np
import io
import pandas as pd
from data_logger import DataLogger


def trajectory_generator(path: str, preview=False):
    """
    in case the trajectory is splitted into multiple files, this generator can be used to iterate over all of them
    """
    trajectory = pd.read_csv(path)
    if preview:
        trajectory = trajectory.iloc[:500]
    for i in range(len(trajectory)):
        yield trajectory.iloc[i]
    
def unpack_point(point):
    position = point[['x', 'y', 'z']].to_numpy()
    orientation = point[['qw', 'qx', 'qy', 'qz']].to_numpy()
    return position, orientation

def test():
    world, dimenvue = setup_sim()
        
    trajectory = trajectory_generator('./data/trajectory/office2/400/0.csv', preview=False)
    path_iter = iter(trajectory)

    dimenvue.set_local_pose(*unpack_point(next(path_iter)))
    
    running = True
    def path_advance(event):
        nonlocal running
        try:
            dimenvue.set_local_pose(*unpack_point(next(path_iter)))            
        except StopIteration:
            running = False
    
    world.add_physics_callback("path_advance", path_advance)
    
    def compress(data_frame):
        for cam in data_frame['cameras']:
            data_frame['cameras'][cam]['compressed'] = []
            for frame in data_frame['cameras'][cam]['rgba']:
                if np.prod(frame.shape) == 0:
                    data_frame['cameras'][cam]['compressed'].append(None)
                    continue
                rgba_image = Image.fromarray(frame, 'RGBA')
                buffer = io.BytesIO()
                rgba_image.save(buffer, format="PNG")
                png_bytes = buffer.getvalue()
                buffer.close()
                data_frame['cameras'][cam]['compressed'].append(png_bytes)
            del data_frame['cameras'][cam]['rgba']
        return data_frame
    
    logger = DataLogger('office_sim', chunk_size_mb=500)
    # doesn't really help. using tar on the uncompressed data is easier
    # logger.set_transform(compress)
    
    world.reset(soft=True)
    while running:
        world.step()
        current_data = dimenvue.consume_frame()
        logger.log(current_data)


test()
# Out:
# skip empty frame
# [9.645s] Simulation App Startup Complete
# 2024-12-21 07:28:09 [42,330ms] [Error] [omni.physx.plugin] PhysX error: PxRigidDynamic::setLinearVelocity: Body must be non-kinematic!, FILE /builds/omniverse/physics/physx/source/physx/src/NpRigidDynamic.cpp, LINE 232
# 2024-12-21 07:28:09 [42,330ms] [Error] [omni.physx.plugin] PhysX error: PxRigidDynamic::setAngularVelocity: Body must be non-kinematic!, FILE /builds/omniverse/physics/physx/source/physx/src/NpRigidDynamic.cpp, LINE 256
# 2024-12-21 07:28:09 [42,647ms] [Error] [omni.physx.plugin] PhysX error: PxRigidDynamic::setLinearVelocity: Body must be non-kinematic!, FILE /builds/omniverse/physics/physx/source/physx/src/NpRigidDynamic.cpp, LINE 232
# 2024-12-21 07:28:09 [42,647ms] [Error] [omni.physx.plugin] PhysX error: PxRigidDynamic::setAngularVelocity: Body must be non-kinematic!, FILE /builds/omniverse/physics/physx/source/physx/src/NpRigidDynamic.cpp, LINE 256
# skip empty frame

# %% [markdown]
# # 5. Visualize and debug

# %%
import sys
import os

import numpy as np
import pandas as pd
import rerun as rr

from matplotlib import pyplot as plt

from rotations import *

rr.init('office_trajectory', spawn=True)


def Axes(length=1.0):
    return rr.Arrows3D(
        vectors=[[length, 0, 0], [0, length, 0], [0, 0, length]],
        colors=[[255,0,0], [0,255,0], [0,0,255]],
    )

rr.log('/world', Axes(0.1), static=True)
# Out:
# [2024-12-10T01:29:54Z INFO  re_sdk_comms::server] Hosting a SDK server over TCP at 0.0.0.0:9876. Connect with the Rerun logging SDK.
# [2024-12-10T01:29:54Z INFO  winit::platform_impl::platform::x11::window] Guessed window scale factor: 1
# [2024-12-10T01:29:54Z INFO  re_sdk_comms::server] New SDK client connected from: 127.0.0.1:40144

# %%
import json
import sys
import os

import numpy as np
import pandas as pd
import rerun as rr

from matplotlib import pyplot as plt

from rotations import *

rr.init('office_trajectory', spawn=True)


def Axes(length=1.0):
    return rr.Arrows3D(
        vectors=[[length, 0, 0], [0, length, 0], [0, 0, length]],
        colors=[[255,0,0], [0,255,0], [0,0,255]],
    )

rr.log('/world', Axes(0.1), static=True)

def rr_transform(pos:np.ndarray, angles:np.ndarray):
    wxyz = euler_angles_to_quat(angles, degrees=True, extrinsic=True)
    xyzw = np.roll(wxyz, -1)
    return rr.Transform3D(
        translation=pos,
        quaternion=xyzw
    )

def rr_set_up_frame():
    # world, dimenvue = setup_sim()
    # dimenvue_config = dimenvue.config
    dimenvue_config = json.load(open('dimenvue_config.json'))
    rr.set_time_seconds('sim_time', 0.0)
    rr.log('/world', rr.Clear(recursive=True))
    rr.log('/world', Axes(1), static=True)
    c = dimenvue_config['chassis']
    p, r = c['world_chassis_translate'], c['world_chassis_rotate']
    rr.log('/world/chassis', rr_transform(p, r))
    rr.log('/world/chassis', Axes(1))
    if 'lidar' in dimenvue_config:
        c = dimenvue_config['lidar']
        p, r = c['chassis_lidar_translate'], c['chassis_lidar_rotate']
        rr.log('/world/chassis/lidar', rr_transform(p, r))
        rr.log('/world/chassis/lidar', Axes(1))
    if 'cameras' in dimenvue_config:
        c = dimenvue_config['cameras']
        p, r = c['chassis_cameras_translate'], c['chassis_cameras_rotate']
        rr.log('/world/chassis/cameras', rr_transform(p, r))
        for i in range(c['num_cameras']):
            p, r = c['camera_translate'][i], c['camera_rotate'][i]
            rr.log(f'/world/chassis/cameras/camera{i}', rr_transform(p, r))
            rr.log(f'/world/chassis/cameras/camera{i}', Axes(1))
    
            calib = c['calibrate_config']
            w, h = calib['camera_resolution']
            if calib['use_intrinsics']:
                ((fx, _, cx),(_,fy,cy),(_,_,_)) = calib['camera_intrinsics']
                f = (fx+fy)/2
            else:
                h_fov = calib['horizontal_fov_deg']*np.pi/180
                f = w/(2*np.tan(h_fov/2))
                cx, cy = w/2, h/2
                
            rr.log(f'/world/chassis/cameras/camera{i}/image', rr.Pinhole(
                resolution=(w,h),
                camera_xyz=rr.ViewCoordinates.RDF, #same as ROS
                focal_length=(f, f),
                principal_point=(cx, cy),
                image_plane_distance=1.0
            ))

rr_set_up_frame()

# %%
def log_rgb(data):
    rr.set_time_seconds('sim_time', 0)

# %%
import pickle

dump_file = './data/trajectory/office/30/lidar_OS1_REV6_32ch10hz512res.pkl'

import pickle

with open(dump_file, 'rb') as f:
    lidar_data = pickle.load(f)

# %%
TF_chassis_lidar = np.eye(4)
TF_chassis_lidar[:3, :3] = euler_to_rot_matrix(dimenvue_config['lidar']['chassis_lidar_rotate'], degrees=True)
TF_chassis_lidar[:3, 3] = dimenvue_config['lidar']['chassis_lidar_translate']


def get_transform(p, q):
    TF_world_chassis = np.eye(4)
    TF_world_chassis[:3, :3] = quat_to_rot_matrix(q)
    TF_world_chassis[:3, 3] = p
    return np.dot(TF_world_chassis, TF_chassis_lidar)

def transform(points, TF):
    if points.size == 0:
        return points
    points_world = np.dot(TF[:3, :3], points.T).T + TF[:3, 3]
    return points_world

# %%
# log lidar data
lidar_data = lidar_data['lidar']
for frame in lidar_data:
    t = frame['rendering_time']
    points = frame['xyz']
    rr.set_time_seconds('sim_time', t)
        
    position = frame['chassis_position']
    orientation_wxyz = frame['chassis_orientation']
    orientation_xyzw = xyzw(orientation_wxyz)
    
    rr.log(f'/world/chassis', rr.Transform3D(translation=position, quaternion=orientation_xyzw))
    rr.log(f'/world/chassis/lidar/points', rr.Points3D(points))
    TF = get_transform(position, orientation_wxyz)
    points_world = transform(points, TF)
    rr.log(f'/world/map/{t}', rr.Points3D(points_world))
